# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Reading the Dataset
dataset = pd.read_csv('Social_Network_Ads.csv')
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.astype(int)
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']
indep
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int32

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':['auto','scale'],
             'C':[10,100,1000,2000,3000]} 



grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
print(re)
grid_predictions = grid.predict(X_test) 
   
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)
# Out:
# {'mean_fit_time': array([0.03436923, 0.00624342, 0.00312381, 0.00312433, 0.00624871,
#        0.00312448, 0.01249676, 0.01332164, 0.01712918, 0.00779428,
#        0.02326717, 0.00231738, 0.02422471, 0.00676851, 0.03063793,
#        0.00358844, 0.10283256, 0.01127653, 0.17491236, 0.00489211,
#        0.11146255, 0.01268206, 0.24340687, 0.00498996, 0.27204843,
#        0.02103443, 0.39555311, 0.00312428, 0.27499208, 0.02499409,
#        0.39413838, 0.00312428, 0.30732775, 0.03097506, 0.58874016,
#        0.00312433, 0.29431877, 0.02429175, 0.65599318, 0.        ]), 'std_fit_time': array([0.04570303, 0.0076466 , 0.00624762, 0.00624866, 0.00765308,
#        0.00624895, 0.00624838, 0.00287296, 0.00636586, 0.00677998,
#        0.00471086, 0.00195974, 0.01021731, 0.00134772, 0.01184661,
#        0.0018443 , 0.01605677, 0.00611373, 0.04354273, 0.00572852,
#        0.01509488, 0.0014118 , 0.14824029, 0.0010626 , 0.15872915,
#        0.00806649, 0.10707678, 0.00624857, 0.14489476, 0.01249716,
#        0.09993842, 0.00624857, 0.05666846, 0.00566441, 0.15210062,
#        0.00624866, 0.04927932, 0.00638534, 0.28037906, 0.        ]), 'mean_score_time': array([0.00624876, 0.00624342, 0.00624814, 0.01249819, 0.00624819,
#        0.00624895, 0.        , 0.00411525, 0.00635586, 0.00359907,
#        0.00441294, 0.00532656, 0.00401168, 0.00443387, 0.00438709,
#        0.00669804, 0.00819836, 0.00312424, 0.00641656, 0.00363173,
#        0.00578074, 0.00434499, 0.00465465, 0.00418878, 0.00764532,
#        0.00483384, 0.00104938, 0.00312433, 0.00997162, 0.00312438,
#        0.00291228, 0.00312433, 0.0030376 , 0.00492001, 0.00079794,
#        0.00312791, 0.00312448, 0.0070621 , 0.        , 0.00624804]), 'std_score_time': array([0.00765314, 0.0076466 , 0.00765238, 0.00624909, 0.00765244,
#        0.79628353, 0.92351003, 0.84702007, 0.9245283 , 0.79628353]), 'split4_test_score': array([0.90174425, 0.94304148, 0.90174425, 0.76655568, 0.90174425,
#        0.94304148, 0.90174425, 0.76655568, 0.90174425, 0.94304148,
#        0.90174425, 0.76655568, 0.90174425, 0.94304148, 0.90174425,
#        0.76655568, 0.90174425, 0.92351003, 0.90174425, 0.76655568,
#        0.90174425, 0.92351003, 0.90174425, 0.76655568, 0.90174425,
#        0.90361034, 0.90174425, 0.76655568, 0.90174425, 0.90361034,
#        0.90174425, 0.76655568, 0.90174425, 0.88327784, 0.90174425,
#        0.76655568, 0.90174425, 0.88327784, 0.90174425, 0.76655568]), 'mean_test_score': array([0.81814583, 0.90223638, 0.84444547, 0.74404546, 0.81814583,
#        0.90223638, 0.84444547, 0.75987902, 0.81814583, 0.90236709,
#        0.84044073, 0.72852603, 0.81814583, 0.90236709, 0.84044073,
#        0.75696202, 0.81814583, 0.8787079 , 0.83609468, 0.75352707,
#        0.81814583, 0.88288362, 0.83609468, 0.75696202, 0.81814583,
#        0.86703213, 0.83609468, 0.75352707, 0.81814583, 0.86703213,
#        0.83609468, 0.75696202, 0.81814583, 0.85501116, 0.83609468,
#        0.75352707, 0.81814583, 0.85501116, 0.83609468, 0.75696202]), 'std_test_score': array([0.08361871, 0.0344308 , 0.05691772, 0.04774326, 0.08361871,
#        0.0344308 , 0.05691772, 0.01317221, 0.08361871, 0.03430808,
#        0.0623702 , 0.05862459, 0.08361871, 0.03430808, 0.0623702 ,
#        0.04374543, 0.08361871, 0.03950322, 0.06654053, 0.04004831,
#        0.08361871, 0.03452908, 0.06654053, 0.04374543, 0.08361871,
#        0.02694806, 0.06654053, 0.04004831, 0.08361871, 0.02694806,
#        0.06654053, 0.04374543, 0.08361871, 0.01920646, 0.06654053,
#        0.04004831, 0.08361871, 0.01920646, 0.06654053, 0.04374543]), 'rank_test_score': array([21,  3, 11, 39, 21,  3, 11, 31, 21,  1, 13, 40, 21,  1, 13, 32, 21,
#         6, 15, 36, 21,  5, 15, 32, 21,  7, 15, 36, 21,  7, 15, 32, 21,  9,
#        15, 36, 21,  9, 15, 32])}

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9100355779243318

# %%
print(cm)
# Out:
# [[80  5]
#  [ 7 42]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 from sklearn.metrics import roc_auc_score
# ----> 3 roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:31, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      25 attr_err = AttributeError(
#      26     f"This {repr(owner.__name__)} has no attribute {repr(self.attribute_name)}"
#      27 )
#      28 if obj is not None:
#      29     # delegate only on instances, not the classes.
#      30     # this is to allow access to the docstrings.
# ---> 31     if not self.check(obj):
#      32         raise attr_err
#      33     out = MethodType(self.fn, obj)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:364, in _estimator_has.<locals>.check(self)
#     361 _check_refit(self, attr)
#     362 if hasattr(self, "best_estimator_"):
#     363     # raise an AttributeError if `attr` does not exist
# --> 364     getattr(self.best_estimator_, attr)
#     365     return True
#     366 # raise an AttributeError if `attr` does not exist
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:31, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      25 attr_err = AttributeError(
#      26     f"This {repr(owner.__name__)} has no attribute {repr(self.attribute_name)}"
#      27 )
#      28 if obj is not None:
#      29     # delegate only on instances, not the classes.
#      30     # this is to allow access to the docstrings.
# ---> 31     if not self.check(obj):
#      32         raise attr_err
#      33     out = MethodType(self.fn, obj)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:827, in BaseSVC._check_proba(self)
#     825 def _check_proba(self):
#     826     if not self.probability:
# --> 827         raise AttributeError(
#     828             "predict_proba is not available when  probability=False"
#     829         )
#     830     if self._impl not in ("c_svc", "nu_svc"):
#     831         raise AttributeError("predict_proba only implemented for SVC and NuSVC")
#
# AttributeError: predict_proba is not available when  probability=False

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.034369      0.045703         0.006249        0.007653      10
# 1        0.006243      0.007647         0.006243        0.007647      10
# 2        0.003124      0.006248         0.006248        0.007652      10
# 3        0.003124      0.006249         0.012498        0.006249      10
# 4        0.006249      0.007653         0.006248        0.007652      10
# 5        0.003124      0.006249         0.006249        0.007653      10
# 6        0.012497      0.006248         0.000000        0.000000      10
# 7        0.013322      0.002873         0.004115        0.003737      10
# 8        0.017129      0.006366         0.006356        0.006302     100
# 9        0.007794      0.006780         0.003599        0.002051     100
# 10       0.023267      0.004711         0.004413        0.002583     100
# 11       0.002317      0.001960         0.005327        0.005425     100
# 12       0.024225      0.010217         0.004012        0.002334     100
# 13       0.006769      0.001348         0.004434        0.000388     100
# 14       0.030638      0.011847         0.004387        0.002319     100
# 15       0.003588      0.001844         0.006698        0.004482     100
# 16       0.102833      0.016057         0.008198        0.006342    1000
# 17       0.011277      0.006114         0.003124        0.006248    1000
# 18       0.174912      0.043543         0.006417        0.004689    1000
# 19       0.004892      0.005729         0.003632        0.006075    1000
# 20       0.111463      0.015095         0.005781        0.005283    1000
# 21       0.012682      0.001412         0.004345        0.000403    1000
# 22       0.243407      0.148240         0.004655        0.002917    1000
# 23       0.004990      0.001063         0.004189        0.000977    1000
# 24       0.272048      0.158729         0.007645        0.006644    2000
# 25       0.021034      0.008066         0.004834        0.005952    2000
# 26       0.395553      0.107077         0.001049        0.002099    2000
# 27       0.003124      0.006249         0.003124        0.006249    2000
# 28       0.274992      0.144895         0.009972        0.006985    2000
# 29       0.024994      0.012497         0.003124        0.006249    2000
# 30       0.394138      0.099938         0.002912        0.004034    2000
# 31       0.003124      0.006249         0.003124        0.006249    2000
# 32       0.307328      0.056668         0.003038        0.006075    3000
# 33       0.030975      0.005664         0.004920        0.005724    3000
# 34       0.588740      0.152101         0.000798        0.001596    3000
# 35       0.003124      0.006249         0.003128        0.006256    3000
# 36       0.294319      0.049279         0.003124        0.006249    3000
# 37       0.024292      0.006385         0.007062        0.008744    3000
# 38       0.655993      0.280379         0.000000        0.000000    3000
# 39       0.000000      0.000000         0.006248        0.007652    3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto         poly
# 3         auto      sigmoid
# 4        scale       linear
# 5        scale          rbf
# 6        scale         poly
# 7        scale      sigmoid
# 8         auto       linear
# 9         auto          rbf
# 10        auto         poly
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale          rbf
# 14       scale         poly
# 15       scale      sigmoid
# 16        auto       linear
# 17        auto          rbf
# 18        auto         poly
# 19        auto      sigmoid
# 20       scale       linear
# 21       scale          rbf
# 22       scale         poly
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto         poly
# 27        auto      sigmoid
# 28       scale       linear
# 29       scale          rbf
# 30       scale         poly
# 31       scale      sigmoid
# 32        auto       linear
# 33        auto          rbf
# 34        auto         poly
# 35        auto      sigmoid
# 36       scale       linear
# 37       scale          rbf
# 38       scale         poly
# 39       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 2        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.799620
# 3     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.762677
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 5        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 6       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.799620
# 7    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.762677
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 9        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 10      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.808927
# 12   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 13      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 14     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 15  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.808927
# 16   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 17      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 18     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 19  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 20  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 21     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.847141
# 22    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 24   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 25      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 26     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 27  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 28  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 29     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 30    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
# 32   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.776290
# 33      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.826263
# 34     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 35  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.791752
# 36  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.776290
# 37     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.826263
# 38    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.808927
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0